# %%
import mysql.connector

conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")

c=conn.cursor()

c.execute("update student set branch ='cs' where branch = 'AI'")

conn.commit()

# %%
pip show mysql-connector-python
# Out:
# Name: mysql-connector-python
# Version: 8.4.0
# Summary: MySQL driver written in Python
# Home-page: http://dev.mysql.com/doc/connector-python/en/index.html
# Author: Oracle and/or its affiliates
# Author-email:
# License: GNU GPLv2 (with FOSS License Exception)
# Location: /home/shyam/.local/lib/python3.8/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector

conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")

c=conn.cursor()

c.execute("alter table student add column percentage int default 90")


conn.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[5], line 7
#       3 conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")
#       5 c=conn.cursor()
# ----> 7 c.execute("alter student add column percentage int default 90")
#       9 conn.commit()
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/cursor.py:748, in MySQLCursor.execute(self, operation, params, multi)
#     745     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     747 try:
# --> 748     self._handle_result(self._connection.cmd_query(stmt))
#     749 except InterfaceError as err:
#     750     if self._connection.have_next_result:
#
# File ~/.local/lib/python3.8/site-packages/mysql/connector/opentelemetry/context_propagation.py:102, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
# ...

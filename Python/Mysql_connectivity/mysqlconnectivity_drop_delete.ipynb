# %%
import  mysql.connector

conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")

c=conn.cursor()

c.execute("delete from student where branch='cs'")
conn.commit()

# %%
import  mysql.connector

conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")

c=conn.cursor()

c.execute("alter table student drop column city")
conn.commit()

# %%
import  mysql.connector

conn=mysql.connector.connect(host="localhost",user="root",passwd="root",database="gauri")

c=conn.cursor()

c.execute("drop table student")
conn.commit()
